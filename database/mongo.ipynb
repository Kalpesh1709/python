# %%
import pymongo

# %%
uri = "mongodb+srv://test:<db_password>@cluster0.ikewk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://test:test@cluster0.ikewk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pymongo
client=pymongo.MongoClient("mongodb+srv://test:test@cluster0.ikewk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db= client['test1']
database_name = "morning"

# %%
collection=db[database_name]
Record =[{
    "_id":'7',
    "name":'alpsh',
    'addres':'ganesh nivas'

},
{
    "_id":'8',
    "name":'alpsh',
    'addres':'ganeh nivas'

},
{
    "_id":'9',
    "name":'alsh',
    'addres':'ganeh nvas'

}]
collection.insert_many(Record)
# Out:
# InsertManyResult(['7', '8', '9'], acknowledged=True)

# %%
quary ={ "name":'kalpesh'}
collection.delete_one(quary)
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738668115, 25), 't': 598}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738668115, 25), 'signature': {'hash': b'\x1a\x0f\x84\xbe\x98\xf2\xa6\xff\xe7I\x7f\xd7\x10Oy\xdd=\x90\x1d\x08', 'keyId': 7433201694759976969}}, 'operationTime': Timestamp(1738668115, 25)}, acknowledged=True)

# %%
quary ={'addres':'ganeh nvas'}
data =collection.find(quary)
for i in data:
    print(i)

# %%
quary={'_id': {'$gt':'1'}}
data =collection.find(quary)
for i in data:
    print(i)

# %%
quary={'_id': '4', 'name': 'alpsh', 'addres': 'ganesh nivas'}
collection.delete_one(quary)
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738669107, 1), 't': 598}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738669107, 1), 'signature': {'hash': b'\xd4\x96*\x8bFLX\xac(\x82\xdf8G>\xbf7\xdbi6\x81', 'keyId': 7433201694759976969}}, 'operationTime': Timestamp(1738669107, 1)}, acknowledged=True)

# %%
quary_dete ={'_id':{'$gt':'6'}}
collection.delete_many(quary)
# Out:
# DeleteResult({'n': 8, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738669514, 24), 't': 598}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738669514, 24), 'signature': {'hash': b'nj>R\xf6\xe3\x08\xf1\xf7\x99\xba\x03\xcd\x0b\xc6\xcf/|r\xe7', 'keyId': 7433201694759976969}}, 'operationTime': Timestamp(1738669514, 24)}, acknowledged=True)

# %%
prsent ={'addres':'ganeh nvas'}
new = {'$set':{'addres':'ganeh nivas'}}
collection.update_one(prsent,new)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738669945, 20), 't': 598}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738669945, 20), 'signature': {'hash': b'h\xb9\x85r\x92\xeaW4\x11\xe6Z^\xa9\xe8h\x83 ;\x1fo', 'keyId': 7433201694759976969}}, 'operationTime': Timestamp(1738669945, 20), 'updatedExisting': True}, acknowledged=True)

# %%
pwd()
# Out:
# 'C:\\Users\\KalpeshThakre'

# %%
import csv
location1 ='C:\\Users\\KalpeshThakre\\Downloads\\carbon+nanotubes\\nanotubes.csv'
with open(location1, 'r', encoding='utf-8') as f:
    data =f.read()

# %%
collection = data.split(';')

# %%
collection
# Out:
# ['Chiral indice n',
#  'Chiral indice m',
#  'Initial atomic coordinate u',
#  'Initial atomic coordinate v',
#  'Initial atomic coordinate w',
#  "Calculated atomic coordinates u'",
#  "Calculated atomic coordinates v'",
#  "Calculated atomic coordinates w'\n2",
#  '1',
#  '0,679005',
#  '0,701318',
#  '0,017033',
#  '0,721039',
#  '0,730232',
#  '0,017014\n2',
#  '1',
#  '0,717298',
#  '0,642129',
#  '0,231319',
#  '0,738414',
#  '0,65675',
#  '0,232369\n2',
#  '1',
#  '0,489336',
#  '0,303751',
#  '0,088462',
#  '0,477676',
#  '0,263221',
#  '0,088712\n2',
#  '1',
#  '0,413957',
#  '0,632996',
#  '0,040843',
#  '0,408823',
#  '0,657897',
#  '0,039796\n2',
#  '1',
#  '0,334292',
#  '0,543401',
#  '0,15989',
#  '0,303349',
#  '0,558807',
#  '0,157373\n2',
#  '1',
#  '0,510664',
#  '0,696249',
#  '0,255128',
#  '0,496977',
#  '0,725608',
#  '0,25597\n2',
#  '1',
#  '0,413957',
#  '0,632996',
#  '0,374176',
#  '0,390878',
#  '0,657645',
#  '0,374735\n2',
#  '1',
#  '0,712552',
# ...

# %%
type(collection)
# Out:
# list

# %%
rows = [collection[i:i+8] for i in range(0, len(collection), 8)]

# %%
with open('output.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(rows)

print("CSV file created with rows of 8 elements each!")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 with open('output.csv', mode='w', newline='') as file:
#       2     writer = csv.writer(file)
#       3     writer.writerows(rows)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'output.csv'

# %%
pwd()
# Out:
# 'c:\\Users\\KalpeshThakre\\OneDrive - Ncubate India Services Pvt Ltd\\Desktop\\Python_testing\\mongodb'
