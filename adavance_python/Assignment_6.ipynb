# %% [markdown]
# **Q1. Describe three applications for exception processing.**

# %% [markdown]
# **Ans:**
#
# Exception Processing is important to find exceptions that causes the runtime error as runtime errors halt the program execution when exception occurs.
#
# Exception Processing is used in Various Applications. Few examples are:
#
# 1)Checking Appropriate use of input in an application
#
# 2)Checking for Arithmetic exceptions in mathematical executions
#
# 3)Checking File I/O exceptions during File handling

# %% [markdown]
# **Q2. What happens if you don&#39;t do something extra to treat an exception?**

# %% [markdown]
# **Ans:**
#
# if we dont do something extra to treat an exception then run time error occure and whole program crash due to run time error

# %% [markdown]
# **Q3.What are your options for recovering from an exception in your script?**

# %% [markdown]
# **Ans:**
#
# we can avoid run time error using 'try' and except block for continus executing of script without run time error

# %% [markdown]
# **Q4. Describe two methods for triggering exceptions in your script.**

# %% [markdown]
# **Ans:**
#
# raise and assert are two methods that can be used to trigger manual exceptions in our script.
#
# **raise** method triggers an exception if condition provided to it turns out to be True.
#
#
#  **assert**  will let the program to continue execution if condition provided to it turns out to be True else exception will be raised

# %%
x=0
if(x==0):
  raise Exception ("value 0")
else:
  x =1
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-7d3f96c5e139> in <cell line: 2>()
#       1 x=0
#       2 if(x==0):
# ----> 3   raise Exception ("value 0")
#       4 else:
#       5   x =1
#
# Exception: value 0

# %%
x= 10
assert x==5 ,"not equal to 5"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-ebe42db6b3ec> in <cell line: 2>()
#       1 x= 10
# ----> 2 assert x==5 ,"not equal to 5"
#
# AssertionError: not equal to 5

# %% [markdown]
# **Q5. Identify two methods for specifying actions to be executed at termination time, regardless of whether or not an exception exists.**

# %% [markdown]
# **Ans:**
#
# Python Provides **else and finally** blocks for specifying actions to be executed at termination time, regardless of whether an exceptions exists or not.
