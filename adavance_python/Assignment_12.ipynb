# %% [markdown]
# **Q1. Does assigning a value to a string&#39;s indexed character violate Python&#39;s string immutability?**

# %% [markdown]
# **Ans**
#
# Yes, assigning a value to a string's indexed character does violate Python's string immutability lets see below example
#
# In this example we are trying to modify current string but we are getting below type error.
#
#
# TypeError: 'str' object does not support item assignment
#
# if we want to modify string we need to create new string lets see

# %%
s = "hello"
s[0] ='H'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ba580800e087> in <cell line: 2>()
#       1 s = "hello"
# ----> 2 s[0] ='H'
#
# TypeError: 'str' object does not support item assignment

# %%
s="hello"
s = "H"+s[1:]
s
# Out:
# 'Hello'

# %% [markdown]
# **Q2.Does using the += operator to concatenate strings violate Python&#39;s string immutability? Why or why not?**

# %% [markdown]
# **Ans:**
#
#
#  += operator donot  modify string its create new string so += operator to concatenate string does not violet Python's string immutability

# %% [markdown]
# **Q3. In Python, how many different ways are there to index a character?**

# %% [markdown]
# **Ans:**
#
# 1) postive indexing - its starting from first character
#
# 2) negative indexing - its starting from last  character
#
# 3) postive slicing - Extracts a substring using a range of positive indices
#
# 4) negative slicing -Extracts a substring using a range of negative indices
#
# lets see below example:

# %%
name = " kalpesh Thakare"
print(f"positive indexing name[0] :{name[0]}")# K
print(f"negative indexing name[-1] :{name[-1]}")#e
print(f"positive slicing name[3:8] :{name[3:8]}")#esh
print(f"negative slicing name[-5:-1] :{name[-5:-1]}")#akar
# Out:
# positive indexing name[0] :
# negative indexing name[-1] :e
# positive slicing name[3:8] :lpesh
# negative slicing name[-1:-5] :akar

# %% [markdown]
# **Q4. What is the relationship between indexing and slicing?**

# %% [markdown]
# **Ans:**
#
# Indexing is a special case of slicing where only a single element is retrieved. For example, my_list[2] is equivalent to my_list[2:3][0].
#
# Slicing allows for more flexibility by enabling access to multiple elements at once, whereas indexing is limited to just one element.
#
# Both use zero-based indexing: The first element is at index 0.
#
# In summary, while indexing gets you one element, slicing gets you a range of elements. Slicing can be thought of as an extension of indexing.

# %% [markdown]
# **Q5. What is an indexed character&#39;s exact data type? What is the data form of a slicing-generated substring?**

# %% [markdown]
# **Ans:**
#
# index character and slicing datatype both are string lets see bwlow example:

# %%
myname = "kalpesh thakare"
print(type(myname[0]))
print(type(myname[6:9]))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# **Q6. What is the relationship between string and character &quot;types&quot; in Python?**

# %% [markdown]
# **Ans:**
#
# Python, a character is just a tiny string. Both are treated as str.

# %% [markdown]
# **Q7. Identify at least two operators and one method that allow you to combine one or more smaller strings to create a larger string.**

# %% [markdown]
# **Ans:**
#
# we can convert small string into large string using below method
#
# **1. operator**
#
# 1)+ operator use for merege 2 string
#
# 2) * operator use for repeat number of times
#
#
# **2. method**
#
#  join method use to join string
#
#  lets see below example:

# %%
name = "kalpesh"
# * repeat
print(f"using * operator:\n{3*name}")

name+=" data science"
print(f"using += operator:\n{name}")

name= " ".join(('e','x','p','e','r','t'))
print(f"using join method:\n{name}")
# Out:
# using * operator:
# kalpeshkalpeshkalpesh
# using += operator:
# kalpesh data science
# using join method:
# e x p e r t

# %% [markdown]
# Q8. What is the benefit of first checking the target string with in or not in before using the index
# method to find a substring?

# %% [markdown]
# **Ans:**
#
# Checking the target string with in or not Operators before using the index method to find a substring just helps confirming availability of substring and thus avoid raising of ValueError.
#
# Example:
#
# in_string = "ineuron"
#
# in_string.index('x') # Raises ValueError
#
# in_string.index('u') # 3

# %% [markdown]
# **Q9. Which operators and built-in string methods produce simple Boolean (true/false) results?**

# %% [markdown]
# **Ans:**

# %%
name = "kalpesh"
result = 'k'in name

# %%
result
# Out:
# True

# %% [markdown]
# not in

# %%
result = 'X' not in name

# %%
result
# Out:
# True

# %% [markdown]
# startwith:

# %%
result= name.startswith("ka")

# %%
result
# Out:
# True

# %% [markdown]
# endwith:

# %%
result = name.endswith("esh")
result
# Out:
# True

# %% [markdown]
# isalnum:

# %%
result = name.isalnum()
result
# Out:
# True

# %% [markdown]
# Upper:

# %%
result = name.isupper()
result
# Out:
# False

# %% [markdown]
# list of operators and built-in string methods produce simple Boolean (true/false) results
#
# in
# not
# <string>.isalpha()
#
# <string>.isalnum()
#
# <string>.isdecimal()
#
# <string>.isdigit()
#
# <string>.islower()
#
# <string>.isnumeric()
#
# <string>.isprintable()
#
# <string>.isspace()
#
# <string>.istitle()
