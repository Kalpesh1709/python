# %% [markdown]
# Q1. What is the difference between __getattr__ and __getattribute__?

# %% [markdown]
# **Ans:**
# both are used for retrive data from object lets see purpose of each
#
# getattr: it is inbuild function it retrive attribute from the object and it allow you to specify default if it doesnt exist
#
# getattr is typically used when you need to programmatically access attributes, possibly with a default value.
#
# getattr is a standard function you call directly.
#
# getattr allows you to provide a default value if the attribute does not exist.

# %%
class MyClass:
    attr = 10

obj = MyClass()
print(getattr(obj, 'attr'))        # Output: 10
print(getattr(obj, 'non_existent', 'default'))  # Output: default
# Out:
# 10
# default

# %% [markdown]
# __getattribute__
#
# it is a special method that is called automatically when an attribute is accessed using dot notation. It's part of the object's descriptor protocol and is called by the interpreter.
#
# __ getattribute __ is used for customizing attribute access and is generally used within class definitions.
#
# __ getattribute __ will raise an AttributeError if the attribute does not exist, unless you handle this explicitly within the method.

# %% [markdown]
# **Q2.What is the difference between properties and descriptors?**

# %% [markdown]
# **Ans:**
#
# Ans: The differences between Properties and Descriptors is:
#
# **Properties**: With Properties we can bind getter, setter and delete functions together with an attribute name, using the built-in property function or @property decorator. When we do this, each reference to an attribute looks like simple, direct access, but involes the appropriate function of the object.
#
# **Descriptor**: With Descriptor we can bind getter, setter and delete functions into a seperate class. we then assign an object of this class to the attribute name in our main class. When we do this, each reference to an attribute looks like simple, direct access but invokes an appropriate function of descriptor object

# %% [markdown]
# Q3. What are the key differences in functionality between __getattr__ and __getattribute__, as well as
# properties and descriptors?

# %% [markdown]
# **Ans**
#
# **getattr**
#
#  it is inbuild function it retrive attribute from the object and it allow you to specify default if it doesnt exist
#
# getattr is typically used when you need to programmatically access attributes, possibly with a default value.
#
# getattr is a standard function you call directly.
#
# getattr allows you to provide a default value if the attribute does not exist.
#
# **__ getattribute __**
#
# it is a special method that is called automatically when an attribute is accessed using dot notation. It's part of the object's descriptor protocol and is called by the interpreter.
#
# __ getattribute __ is used for customizing attribute access and is generally used within class definitions.
#
# __ getattribute __ will raise an AttributeError if the attribute does not exist, unless you handle this explicitly within the method.
#
#
# The differences between Properties and Descriptors is:
#
# **Properties:** With Properties we can bind getter, setter and delete functions together with an attribute name, using the built-in property function or @property decorator. When we do this, each reference to an attribute looks like simple, direct access, but involes the appropriate function of the object.
#
# **Descriptor:** With Descriptor we can bind getter, setter and delete functions into a seperate class. we then assign an object of this class to the attribute name in our main class. When we do this, each reference to an attribute looks like simple, direct access but invokes an appropriate function of descriptor object
