# %% [markdown]
# **Q1. Explain the difference between greedy and non-greedy syntax with visual terms in as few words as possible. What is the bare minimum effort required to transform a greedy pattern into a non-greedy one? What characters or characters can you introduce or change?**

# %% [markdown]
# **Ans:**
#  The Main difference between Greedy and Non Greedy Match Syntax is The Greedy Match will try to match as many repetitions of the quantified pattern as possible Whereas The Non Greedy Match will try to match as few repetitions of the quantified pattern as possible

# %%
import re
print(re.findall("v*", "vvvvvv")) # Greedy Match Synatx
print(re.findall("v*?", "vvvvvv")) # Non Greddy Syntax
# Out:
# ['vvvvvv', '']
# ['', 'v', '', 'v', '', 'v', '', 'v', '', 'v', '', 'v', '']

# %% [markdown]
# **Q2. When exactly does greedy versus non-greedy make a difference?  What if you&#39;re looking for a non-greedy match but the only one available is greedy?**

# %% [markdown]
# **Ans:** The Greedy Match will try to match as many repetitions of the quantified pattern as possible. The Non Greedy Match will try to match as few repetitions of the quantified pattern as possible. If only Non Greedy Match is available, we can use other filtering or pattern matching methods of regex and further identify the required pattern.

# %% [markdown]
# **Q3. In a simple match of a string, which looks only for one match and does not do any replacement, is the use of a nontagged group likely to make any practical difference?**

# %% [markdown]
# **Ans**
#
# In this Case The Non Tagged Group will not make any diffrence in this case.

# %%
import re
phone =re.compile(r'\d\d\d\d')
text= phone.search(r'2345678897655')
print(f"tagg: {text.group(0)}")# tagged
print(f"nontagg: {text.group()}")# nontagged
# Out:
# tagg: 2345
# nontagg: 2345

# %% [markdown]
# **Q4. Describe a scenario in which using a nontagged category would have a significant impact on the program&#39;s outcomes.**

# %% [markdown]
# **Ans:**Here in the below Code Snippet . decimal is not tagged or captured. It will useful in scenarios where the separator of value in a string is of no use and we need to capture only the values.

# %%
import re
text='135.456'
pattern=r'(\d+)(?:.)(\d+)'
regobj=re.compile(pattern)
matobj=regobj.search(text)
matobj.groups()
# Out:
# ('135', '456')

# %% [markdown]
# **Q5. Unlike a normal regex pattern, a look-ahead condition does not consume the characters it examines. Describe a situation in which this could make a difference in the results of your programme?**

# %% [markdown]
# **Ans:**
#
# While counting the number of multiple lines or mutiple sentence in a string the positive look ahead makes a difference, without which we wont get the correct count of lines or sentences in a string.

# %% [markdown]
# **Q6. In standard expressions, what is the difference between positive look-ahead and negative look-ahead?**

# %% [markdown]
# **Ans:**
#
# Positive Look-Ahead ((?=...)): Checks for the presence of a pattern following the current position.
#
# Negative Look-Ahead ((?!...)): Checks for the absence of a pattern following the current position.

# %% [markdown]
# **Q7.What is the benefit of referring to groups by name rather than by number in a standard expression?**

# %% [markdown]
# **Ans:**
#
# In summary, named groups enhance clarity and ease of use when working with complex regular expressions.

# %% [markdown]
# **Q8. Can you identify repeated items within a target string using named groups, as in &quot;The cow jumped over the moon&quot;?**

# %%
import re
pattern = re.compile(r'\b(?P<word>\w+)\b.*\b(?P=word)\b', re.IGNORECASE)
text = "The cow jumped over the moon"
match = pattern.search(text)
if match:
    print(f"Repeated word: {match.group('word')}")
else:
    print("No repeated words found")
# Out:
# Repeated word: The

# %% [markdown]
# **Q9. When parsing a string, what is at least one thing that the Scanner interface does for you that the re.findall feature does not?**

# %% [markdown]
# **Ans:** re.findall() module is used to search for all occurrences that match a given pattern. In contrast, re.search() will only return the first occurrence that matches the specified pattern. re.findall() will iterate over all the lines of the file and will return all non-overlapping matches of pattern in a single step.

# %% [markdown]
# **Q10. Does a scanner object have to be named scanner?**

# %% [markdown]
# **Ans:** Yes, It may have any name.
