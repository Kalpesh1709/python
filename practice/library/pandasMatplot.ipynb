# %%
import pandas as pd
import numpy as np

# %%
np.random.randn(10,4)
# Out:
# array([[ 0.32303525,  0.23307481, -0.20946469,  0.73579174],
#        [ 0.36559191,  0.40663246,  3.3467245 ,  0.26570137],
#        [ 0.41708636,  1.08486331, -0.28675127,  1.30617357],
#        [-1.11258722, -0.26823716, -1.66227182, -0.59276808],
#        [ 0.2473375 , -0.5664058 ,  0.40634229, -0.22997081],
#        [-0.83365744, -0.20234289, -0.7197759 , -0.26301194],
#        [ 0.59537411,  1.06566573,  0.20533174, -1.74403302],
#        [-0.81218386, -0.51458411,  0.19453057, -0.7024742 ],
#        [-1.00439063,  0.3411003 , -0.59453562, -0.92473828],
#        [ 0.05540784, -0.43021302,  0.04012008, -0.98834833]])

# %%
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2021-07-18',periods =10),columns=['a','b','c','d'])

# %%
df['new']=df['c']+df['d']

# %%
df
# Out:
#                    a         b         c         d       new
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368

# %%
df['new_col_sqr_d']= df['d'].apply(lambda x :x**2)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_sqr_d
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598       3.342788
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041       7.052379
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378       2.295406
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278       1.905129
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908       0.834748
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321       0.469893
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277       0.838188
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449       1.739854
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181       0.096022
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368       5.900992

# %%
df['new_col_log_d']= df['d'].apply(lambda x :np.log2(x))
# Out:
# C:\Users\KalpeshThakre\AppData\Local\Temp\ipykernel_11844\4185076845.py:1: RuntimeWarning: invalid value encountered in log2
#   df['new_col_log_d']= df['d'].apply(lambda x :np.log2(x))

# %%
def test(x):
    if(x<0):
        return x
    else:
        return np.log(x)

# %%
df['new_col_log_d']= df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_sqr_d  \
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598       3.342788
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041       7.052379
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378       2.295406
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278       1.905129
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908       0.834748
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321       0.469893
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277       0.838188
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449       1.739854
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181       0.096022
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368       5.900992
#
#             new_col_log_d
# 2021-07-18      -1.828329
# 2021-07-19      -2.655632
# 2021-07-20       0.415455
# ...

# %%
def test1(x):
    if x<0:
        return 1
    else:
        return 0

# %%
df['new datta']= df['a'].apply(test1)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_sqr_d  \
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598       3.342788
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041       7.052379
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378       2.295406
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278       1.905129
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908       0.834748
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321       0.469893
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277       0.838188
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449       1.739854
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181       0.096022
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368       5.900992
#
#             new_col_log_d  new datta
# 2021-07-18      -1.828329          1
# 2021-07-19      -2.655632          1
# ...

# %%
df.sort_values(by ='b')
# Out:
#                    a         b         c         d       new  new_col_sqr_d  \
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368       5.900992
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598       3.342788
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378       2.295406
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181       0.096022
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277       0.838188
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908       0.834748
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278       1.905129
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449       1.739854
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041       7.052379
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321       0.469893
#
#             new_col_log_d  new datta
# 2021-07-27      -2.429196          1
# 2021-07-18      -1.828329          1
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'new', 'new_col_sqr_d', 'new_col_log_d',
#        'new datta'],
#       dtype='object')

# %%
df['new date'] = df.index

# %%
df
# Out:
#                    a         b         c         d       new  new_col_sqr_d  \
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598       3.342788
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041       7.052379
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378       2.295406
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278       1.905129
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908       0.834748
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321       0.469893
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277       0.838188
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449       1.739854
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181       0.096022
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368       5.900992
#
#             new_col_log_d  new datta   new date
# 2021-07-18      -1.828329          1 2021-07-18
# ...

# %%
df.dtypes
# Out:
# a                       float64
# b                       float64
# c                       float64
# d                       float64
# new                     float64
# new_col_sqr_d           float64
# new_col_log_d           float64
# new datta                 int64
# new date         datetime64[ns]
# dtype: object

# %%
df['day']= df.index.day
df['month']= df.index.month
df['year']= df.index.year

# %%
df
# Out:
#                    a         b         c         d       new  new_col_sqr_d  \
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598       3.342788
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041       7.052379
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378       2.295406
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278       1.905129
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908       0.834748
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321       0.469893
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277       0.838188
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449       1.739854
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181       0.096022
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368       5.900992
#
#             new_col_log_d  new datta   new date  day  month  year
# 2021-07-18      -1.828329          1 2021-07-18   18      7  2021
# ...

# %%
df['dayname']= df.index.day_name()

# %%
df
# Out:
#                    a         b         c         d       new  new_col_sqr_d  \
# 2021-07-18 -0.793456 -0.690156  0.838731 -1.828329 -0.989598       3.342788
# 2021-07-19 -0.272340  0.897026  1.056590 -2.655632 -1.599041       7.052379
# 2021-07-20 -0.118082 -0.430463 -0.484681  1.515060  1.030378       2.295406
# 2021-07-21  0.276552  0.199441 -0.628014 -1.380264 -2.008278       1.905129
# 2021-07-22 -0.442152 -0.069420  0.387737 -0.913646 -0.525908       0.834748
# 2021-07-23  0.473592  0.954016  0.917833  0.685487  1.603321       0.469893
# 2021-07-24  0.350783 -0.102788 -0.563750 -0.915526 -1.479277       0.838188
# 2021-07-25 -1.120837  0.415489 -0.669586  1.319035  0.649449       1.739854
# 2021-07-26 -1.529588 -0.406604  0.859308  0.309874  1.169181       0.096022
# 2021-07-27 -0.018994 -1.010916  0.829828 -2.429196 -1.599368       5.900992
#
#             new_col_log_d  new datta   new date  day  month  year    dayname
# ...

# %%
f= df.groupby(by='dayname')

# %%
f.count()
# Out:
#            a  b  c  d  new  new_col_sqr_d  new_col_log_d  new datta  new date  \
# dayname
# Friday     1  1  1  1    1              1              1          1         1
# Monday     2  2  2  2    2              2              2          2         2
# Saturday   1  1  1  1    1              1              1          1         1
# Sunday     2  2  2  2    2              2              2          2         2
# Thursday   1  1  1  1    1              1              1          1         1
# Tuesday    2  2  2  2    2              2              2          2         2
# Wednesday  1  1  1  1    1              1              1          1         1
#
#            day  month  year
# dayname
# Friday       1      1     1
# Monday       2      2     2
# Saturday     1      1     1
# Sunday       2      2     2
# Thursday     1      1     1
# Tuesday      2      2     2
# Wednesday    1      1     1

# %%
df.describe()
# Out:
#                a          b          c          d        new  new_col_sqr_d  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000      10.000000
# mean   -0.319452  -0.024438   0.254400  -0.629314  -0.374914       2.447540
# min    -1.529588  -1.010916  -0.669586  -2.655632  -2.008278       0.096022
# 25%    -0.705630  -0.424498  -0.543983  -1.716313  -1.569100       0.835608
# 50%    -0.195211  -0.086104   0.608783  -0.914586  -0.757753       1.822491
# 75%     0.202666   0.361477   0.854164   0.591584   0.935146       3.080942
# max     0.473592   0.954016   1.056590   1.515060   1.603321       7.052379
# std     0.659358   0.648547   0.744455   1.509784   1.358419       2.342419
#
#        new_col_log_d  new datta             new date       day  month    year
# count      10.000000  10.000000                   10  10.00000   10.0    10.0
# mean       -1.097945   0.700000  2021-07-22 12:00:00  22.50000    7.0  2021.0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df =pd.DataFrame(np.random.rand(1000,1),index=pd.date_range('2024-07-09',periods= 1000),columns=['data'])

# %%
df
# Out:
#                 data
# 2024-07-09  0.588131
# 2024-07-10  0.897714
# 2024-07-11  0.891531
# 2024-07-12  0.815837
# 2024-07-13  0.035890
# ...              ...
# 2027-03-31  0.992189
# 2027-04-01  0.756037
# 2027-04-02  0.299186
# 2027-04-03  0.261712
# 2027-04-04  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.data.cumsum().plot()
# Out:
# <Axes: >

# %%
df.data.cumsum()
# Out:
# 2024-07-09      0.588131
# 2024-07-10      1.485845
# 2024-07-11      2.377375
# 2024-07-12      3.193213
# 2024-07-13      3.229102
#                  ...
# 2027-03-31    495.812936
# 2027-04-01    496.568973
# 2027-04-02    496.868159
# 2027-04-03    497.129872
# 2027-04-04    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df['data1']= df.data.cumsum()

# %%
df['data2']=df['data'].apply(lambda x: x**3)

# %%
df
# Out:
#                 data       data1     data2
# 2024-07-09  0.588131    0.588131  0.203433
# 2024-07-10  0.897714    1.485845  0.723458
# 2024-07-11  0.891531    2.377375  0.708613
# 2024-07-12  0.815837    3.193213  0.543014
# 2024-07-13  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2027-03-31  0.992189  495.812936  0.976749
# 2027-04-01  0.756037  496.568973  0.432145
# 2027-04-02  0.299186  496.868159  0.026781
# 2027-04-03  0.261712  497.129872  0.017926
# 2027-04-04  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1 = sns.load_dataset('iris')

# %%
gf= df1.plot(figsize =(5,5),title = 'irish data')
gf.set_xlabel(" x axis")
gf.set_ylabel(" y axis")
# Out:
# Text(0, 0.5, ' y axis')

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.iloc[0][0:4].plot(kind ='bar')
# Out:
# <Axes: >

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2= sns.load_dataset('titanic')

# %%
df2['pclass'].plot(kind='bar',figsize=(10,10))
# Out:
# <Axes: >

# %%
pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df3.plot(kind= 'barh')
# Out:
# <Axes: >

# %%
df3.plot.bar()
# Out:
# <Axes: >

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['sepal_width'].hist()
# Out:
# <Axes: >

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1['sepal_length'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind= 'hist',stacked= True,bins=100,figsize=(10,10),title='histrogram of iris')
# Out:
# <Axes: title={'center': 'histrogram of iris'}, ylabel='Frequency'>

# %%
df1.plot(kind= 'hist',stacked= True,bins=100,figsize=(10,10),title='histrogram of iris',orientation = 'horizontal')
# Out:
# <Axes: title={'center': 'histrogram of iris'}, xlabel='Frequency'>

# %%
df1.hist(figsize=(10,10),color='r',alpha =0.9)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.scatter(x='sepal_width',y='petal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_length'>

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1.plot.scatter(x='sepal_length',y='petal_width',c='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='sepal_width',label= 'sepal_width',s=100,c ='petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x='sepal_length',y='sepal_width',label= 'sepal_width',gridsize= 20)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
d=df.iloc[0]

# %%
d
# Out:
# data     0.588131
# data1    0.588131
# data2    0.203433
# Name: 2024-07-09 00:00:00, dtype: float64

# %%
d.plot.pie(figsize=(10,10))
# Out:
# <Axes: ylabel='2024-07-09 00:00:00'>

# %%
iris = df1.head(3).T

# %%
iris.iloc[0:4].plot.pie(subplots =True, figsize=(10,10),fontsize =20,autopct ='%.2f')
# Out:
# C:\Users\KalpeshThakre\AppData\Local\Temp\ipykernel_11844\1049399316.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris.iloc[0:4].plot.pie(subplots =True, figsize=(10,10),fontsize =20,autopct ='%.2f')
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10))
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df1,diagonal='kde')
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
df['data'].plot(style='r+',label='kalpesh')
# Out:
# <Axes: >

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.24.1'

# %%
df1.iplot()
# Out:
# <div>                            <div id="c2fb5182-61ec-4bcd-bcc1-501aaec2ed23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df2.iplot(kind='scatter',x='fare',y='age',mode='markers',xTitle='fare',yTitle='age')
# Out:
# <div>                            <div id="db75cfe0-2873-4ff3-8ded-e9f6cdd1d3a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
df2.iplot(kind='bar',x='fare',y='age',mode='markers')
# Out:
# <div>                            <div id="c788367f-f8c3-48ba-baac-b91709f1f026" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.set_config_file(theme='pearl')
df2.iplot(kind='scatter',x='fare',y='age',mode='markers',xTitle='fare',yTitle='age')
# Out:
# <div>                            <div id="8a1669ff-6520-4e88-8641-09e6b96e6122" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.themes
# Out:
# <module 'cufflinks.themes' from 'c:\\Users\\KalpeshThakre\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\cufflinks\\themes.py'>

# %% [markdown]
# bokhe tibco
