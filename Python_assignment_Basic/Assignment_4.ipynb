# %% [markdown]
# **1. What exactly is []?**

# %% [markdown]
# it indicate list that contain no item

# %% [markdown]
# **2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)**

# %%
spam=[2,4,6,8,10]
spam[2]='hello'

# %% [markdown]
# **Let&#39;s pretend the spam includes the list [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;] for the next three queries.**
#
#
# **3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?**

# %%
spam=['a','b','c','d']
spam[int(int('3' * 2) / 11)]
# spam[3]='d'
# Out:
# 'd'

# %% [markdown]
# **4. What is the value of spam[-1]?**

# %%
spam[-1]#d
# Out:
# 'd'

# %% [markdown]
# **5. What is the value of spam[:2]?**

# %%
spam[:2]#'a','b'
# Out:
# ['a', 'b']

# %% [markdown]
# **Let&#39;s pretend bacon has the list [3.14, &#39;cat,&#39; 11, &#39;cat,&#39; True] for the next three questions.**
#
# **6. What is the value of bacon.index(&#39;cat&#39;)?**

# %%
bacon=[3.14, 'cat' ,11,'cat', True]
bacon.index('cat')# ans= 1
# Out:
# 1

# %% [markdown]
# **7. How does bacon.append(99) change the look of the list value in bacon?**

# %%
bacon.append(99)
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# **8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?**

# %%
bacon.remove('cat')
print(bacon)
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# **9. What are the list concatenation and list replication operators?**

# %% [markdown]
# list concatenation '+'
#
# list replication '*'
#
# see below example

# %%
a= 'hello'+'my name is kalpesh'
b= 'hey'*2
print(a)
print(b)
# Out:
# hellomy name is kalpesh
# heyhey

# %% [markdown]
# **10. What is difference between the list methods append() and insert()?**

# %% [markdown]
# append()  we can add variable at the end of list
#
# insert() we can add variable any where in the list
#
# see below example

# %%
bacon=[3.14, 'cat' ,11,'cat', True]
data=[3.14, 'cat' ,11,'cat', True]
bacon.append('4')
print(bacon)
data.insert(2,'4')
print(data)
# Out:
# [3.14, 'cat', 11, 'cat', True, '4']
# [3.14, 'cat', '4', 11, 'cat', True]

# %% [markdown]
# **11. What are the two methods for removing items from a list?**

# %% [markdown]
# **Del and remove** mothod use for removing item from a list

# %% [markdown]
# **12. Describe how list values and string values are identical.**

# %% [markdown]
# **Similarities:**
#
# Both support indexing.
#
# Both support slicing.
#
# Both can be iterated over.
#
# **Differences:**
#
# Lists are mutable, but strings are not.
#
# Lists can contain various types of elements, while strings contain characters.
#
# Lists have specific methods and operations, while strings are more limited in terms of operations.

# %% [markdown]
# **13. What&#39;s the difference between tuples and lists?**

# %% [markdown]
# Tuples:
#
# Tuples are immutable object it can not change after creation.
#
# list:
#
# its mutable object its contain change after creation.

# %% [markdown]
# **14. How do you type a tuple value that only contains the integer 42?**

# %%
value=(42,)
type(value)
# Out:
# tuple

# %% [markdown]
# **15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?**

# %%
value1=(2,3,4,5)
value2=[2,3,4,5,6]
List_Con=list[value1]
tuple_con=tuple(value2)
print(List_Con)
print(tuple_con)
# Out:
# list[2, 3, 4, 5]
# (2, 3, 4, 5, 6)

# %% [markdown]
# **16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they
# contain?**

# %% [markdown]
# They contain references to list values

# %% [markdown]
# **17. How do you distinguish between copy.copy() and copy.deepcopy()?**

# %% [markdown]
#  The copy.copy() function will do a shallow copy of a list,
#
#   while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
