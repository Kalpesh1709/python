# %% [markdown]
# **1. What is the result of the code, and why?**

# %%
def func(a, b=6, c=8):
  print(a, b, c)

func(1, 2)
# Out:
# 1 2 8

# %% [markdown]
# **Ans:**in above code func(1,2) a=1 and b=2 and c=8 fuct() change assigned value

# %% [markdown]
# **2.What is the result of this code, and why?**

# %%
 def func(a, b, c=5):
  print(a, b, c)
func(1, c=3, b=2)
# Out:
# 1 2 3

# %% [markdown]
# **Ans:** func(1,c=3,b=2) in the above code a=1 ,b=2,c=3 c=3 is assigned c=5

# %% [markdown]
# **3.How about this code: what is its result, and why?**

# %%
def func(a, *pargs):
  print(a, pargs)
func(1, 2, 3)
# Out:
# 1 (2, 3)

# %% [markdown]
# **Ans:**in func(1,2,3) a=1 and *pargs is assigned (2,3). * means we are passing non keyword arugement

# %% [markdown]
# **4.What does this code print, and why?**

# %%
def func(a, **kargs):
  print(a, kargs)
func(a=1, c=3, b=2)
# Out:
# 1 {'c': 3, 'b': 2}

# %% [markdown]
# **Ans:**  output is 1 {'c': 3, 'b': 2} a= 1 and **kargs is value with key so {'c':3,'b':2}

# %% [markdown]
# **5. What gets printed by this, and explain?**

# %%
def func(a, b, c=8, d=5):
  print(a, b, c, d)
func(1, *(5, 6))
# Out:
# 1 5 6 5

# %% [markdown]
# **Ans:** in above code func(1,*(5,6)) when it call a=1 b=5 c=6 reassigned to c=8 so output of c= 6 and d=5

# %% [markdown]
# **6. what is the result of this, and explain?**

# %%
def func(a, b, c): a = 2; b[0] = 'x'; c['a'] = 'y'
l=1; m=[1]; n={'a':0}
func(l, m, n)
l,m,n
# Out:
# (1, ['x'], {'a': 'y'})

# %% [markdown]
# **Ans:** result will be (1, ['x'], {'a': 'y'}) l=1 for m=[1] assigned elemment ['x'] for n={'a':'y'} n key it will take as it is and 'y' value assigned to n dictionary
