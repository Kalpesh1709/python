# %% [markdown]
# **1. To what does a relative path refer?**

# %% [markdown]
# Ans:
#
# relative path is the folder or file refer current directory not a root directory

# %% [markdown]
# **2. What does an absolute path start with your operating system?**

# %% [markdown]
# Ans:
#
# An absolute path starts with the root directory, which is represented by a forward slash (/) in Unix-based systems and a drive letter in Windows

# %% [markdown]
# **3. What do the functions os.getcwd() and os.chdir() do?**

# %% [markdown]
# Ans:
#
# os.getcwd(): it indicate current working directory
#
# os.chdir(): it is used for changing directory path

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\thaka\\OneDrive\\Desktop\\DataScience'

# %% [markdown]
# change directory:

# %%
os.chdir("c:\\Users\\thaka\\OneDrive\\Desktop\\DataScience\\assignment")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\thaka\\OneDrive\\Desktop\\DataScience\\assignment'

# %% [markdown]
# **4. What are the . and .. folders?**

# %% [markdown]
# Ans:
#
# The . directory entry refers to the current directory you are in.
#
# The .. directory entry refers to the parent directory of the current directory.

# %% [markdown]
# **5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?**

# %% [markdown]
# Ans:
#
# C:\bacon\eggs\ = this is directory name
#
# spam.txt = base name

# %% [markdown]
# **6. What are the three “mode” arguments that can be passed to the open() function?**

# %% [markdown]
# Ans:
#
# 1) write file using open function

# %%
f=open("hello.txt",'w')
f.write("my name is kalpesh")
f.close()

# %% [markdown]
# 2) read file using open function

# %%
f=open("hello.txt",'r')
print(f.read())
f.close()
# Out:
# my name is kalpesh

# %% [markdown]
# 3) append file using open function

# %%
f=open("hello.txt",'a')
f.write("i am datascientist")
f.close()

# %% [markdown]
# **7. What happens if an existing file is opened in write mode?**

# %% [markdown]
# ans:
#
# if an existing file is opened in write mode and we are writing in that file without closing its pointer start at begining position and data will over writted over old data its treat as new file

# %% [markdown]
# **8. How do you tell the difference between read() and readlines()?**

# %% [markdown]
# Ans:
#
# Read():
# entire file treat as a single string if any aurement pass specific byte read through the read() function
#
# readline():
# this function use for reading single line if return empty string there is no more line to read

# %% [markdown]
# **9. What data structure does a shelf value resemble?**

# %% [markdown]
# Ans:
# A shelf value resembles a dictionary value; it has keys and values, along with keys() and values() methods that work similarly to the dictionary methods of the same names.
