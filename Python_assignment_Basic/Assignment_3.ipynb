# %% [markdown]
# **1. Why are functions advantageous to have in your programs?**

# %% [markdown]
# Function use in python program its make code modular,its can be reused insteated of writing double code line and its easy to maintain and debug

# %% [markdown]
# **2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?**

# %% [markdown]
# The Python code inside a function runs when you ask the program to use that function by calling its name with parentheses.

# %% [markdown]
# **3. What statement creates a function?**

# %% [markdown]
# Def statement use to create function after def are assignen function name with parentheses containing any arguments the function takes, end with colon:
# ex
# def data():
# in this example data is function name

# %% [markdown]
# **4. What is the difference between a function and a function call?**

# %% [markdown]
# A function is the definition of what the code should do.
#
# A function call is the actual execution of that code when you want it to run.

# %% [markdown]
# **5. How many global scopes are there in a Python program? How many local scopes?**

# %% [markdown]
# in Python one global scope and local scope is created whenver the function called

# %% [markdown]
# **6. What happens to variables in a local scope when the function call returns?**

# %% [markdown]
# variables defined within the function are no longer accessible or available for use outside of that function.once execution completed or value return. local varible is distroyed or clean

# %% [markdown]
# **7.What is the concept of a return value? Is it possible to have a return value in an expression?**

# %% [markdown]
# Return value of function means function send back value to code.
#
#  a return value in an expression is possible
#
#
# ex:
# result=fun(arg)*2

# %% [markdown]
# **8. If a function does not have a return statement, what is the return value of a call to that function?**

# %% [markdown]
# its non return type function so its return value is None

# %% [markdown]
# **9. How do you make a function variable refer to the global variable?**

# %% [markdown]
# using golbal keyword we can access the variable in function and outside the function
#
# see below example

# %%
global k
def  increament():
  k=0
  k=k+5
  print(k)
increament()
# Out:
# 5

# %% [markdown]
# **10. What is the data type of None?**

# %% [markdown]
#  NoneType. It represents the absence of a value or a null value.

# %% [markdown]
# **11. What does the sentence import areallyourpetsnamederic do?**

# %% [markdown]
# The sentence import areallyourpetsnamederic is not a valid Python import statement

# %% [markdown]
# **12. If you had a bacon() feature in a spam module, what would you call it after importing spam?**

# %% [markdown]
# after importing spam this function called by using spam.bacon()

# %% [markdown]
# **13. What can you do to save a programme from crashing if it encounters an error?**

# %% [markdown]
# Use try and except blocks to catch and handle exceptions.
#
# and finally block statement for cleanup task

# %% [markdown]
# **14. What is the purpose of the try clause? What is the purpose of the except clause?**

# %% [markdown]
# The **try** clause attempts to execute code that might cause errors,
#
#  while the **except** clause handles those errors if they occur, preventing the program from crashing
