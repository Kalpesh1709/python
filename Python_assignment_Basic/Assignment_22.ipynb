# %% [markdown]
# **1. What is the result of the code, and explain?**

# %%
X = 'iNeuron'
def func():
   print(X)

func()
# Out:
# iNeuron

# %% [markdown]
# **Ans:** 'iNeuron' assigned to x to global variable

# %% [markdown]
# **2.What is the result of the code, and explain?**

# %%
X = 'iNeuron'

def func():
  X = 'NI!'
func()

print(X)
# Out:
# iNeuron

# %% [markdown]
# **Ans:** here x='iNeuron' in side func() x='NI!' but  we are not printing

# %% [markdown]
# **3. What does this code print, and why?**

# %%
X = 'iNeuron'

def func():
  X = 'NI'
  print(X)

func()

print(X)
# Out:
# NI
# iNeuron

# %% [markdown]
# **Ans:** it will print  'NI' and 'iNeuron' becuse inside func() local x assigned 'NI' printed'NI' after function golabal value assigned to x= 'iNeuron'

# %% [markdown]
# **4.What output does this code produce? Why?**

# %%
X = 'iNeuron'

def func():
  global X
  X = 'NI'

func()

print(X)
# Out:
# NI

# %% [markdown]
# **ans:** NI it will print because inside function x is global and 'NI value ssigned to x

# %% [markdown]
# **5.What about this code—what’s the output, and why?**

# %%
X = 'iNeuron'
def func():
  X = 'NI'
def nested():
  print(X)
nested()
func()
X

# %% [markdown]
# **6. How about this code: what is its output in Python 3, and explain?**

# %%
def func():
    X = 'NI'
    def nested():
        nonlocal X
        X = 'Spam'
    nested()
    print(X)
func()
# Out:
# Spam

# %% [markdown]
# **Ans:**in nested  x is non local and x = Spam is assigned so output is 'Spam'
