# %% [markdown]
# **1. What are escape characters, and how do you use them?**

# %% [markdown]
# escape charcter is special character with'\'
# here some escape squence example
#
# '\t'- Represents a tab character
#
# '\b'- Represents a backspace character
#
# '\n'- Represents a newline character

# %% [markdown]
# **2. What do the escape characters n and t stand for?**

# %% [markdown]
# '\t'- Represents a tab character
#
#
# '\n'- Represents a newline character

# %% [markdown]
# **3. What is the way to include backslash characters in a string?**

# %% [markdown]
# \\ Represents a backspace character

# %% [markdown]
# **4. The string &quot;Howl&#39;s Moving Castle&quot; is a correct value. Why isn&#39;t the single quote character in the
# word Howl&#39;s not escaped a problem?t**

# %% [markdown]
# "Howl's Moving Castle" this string enclosed in double quate"" so its not create escape problem if its is in single quate'' its create escape problem for avoiding this issue we are using  forward back slash

# %%
'Howl\'s Moving Castle'
# Out:
# "Howl's Moving Castle"

# %% [markdown]
# **5. How do you write a string of newlines if you don&#39;t want to use the n character?**

# %% [markdown]
# python support multiline string
# see below example

# %%
s='''hello
data science course'''
print(s)
# Out:
# hello
# data science course

# %% [markdown]
# **6. What are the values of the given expressions?**
#
# &#39;Hello, world!&#39;[1]  Ans: e
#
# &#39;Hello, world!&#39;[0:5]   Ans: Hello
#
# &#39;Hello, world!&#39;[:5]  Ans: Hello
#
# &#39;Hello, world!&#39;[3:]  Ans:lo, world!

# %% [markdown]
# **7. What are the values of the following expressions?**
#
# &#39;Hello&#39;.upper() Ans: HELLO
#
# &#39;Hello&#39;.upper().isupper() Ans: True
#
# &#39;Hello&#39;.upper().lower()   Ans: hello

# %% [markdown]
# **8. What are the values of the following expressions?**
#
# **&#39;Remember, remember, the fifth of July.&#39;.split()
# &#39;-&#39;.join(&#39;There can only one.&#39;.split())**

# %% [markdown]
# Remember, remember, the fifth of July.'.split()
#
# **ans:**
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
#
#  '-'.join('There can only one.'.split())
#
# **ans:**
# There-can-only-one.

# %% [markdown]
# **9. What are the methods for right-justifying, left-justifying, and centering a string?**

# %% [markdown]
#  The rjust(),ljust(),center() string methods, respectively

# %% [markdown]
# **10. What is the best way to remove whitespace characters from the start or end?**

# %% [markdown]
# The lstrip() and rstrip() methods remove whitesapce characters from the left and right ends of a string respectively
