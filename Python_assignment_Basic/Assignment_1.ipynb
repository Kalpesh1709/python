# %% [markdown]
#  **Question -1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.**
#
# **'hello'**,
# **-87.8**,
# **-**,
# **/**,
# **+**,
# **6**

# %% [markdown]
# Ans:
#
# 'hello'     - string
#
# -87.8       - float
#
# /+-*           -mathamitcal operator
#
# 6            - int

# %% [markdown]
# **Question 2. What is the difference between string and variable?**

# %% [markdown]
# **Strings:**
#  They represent textual data and are used to store and manipulate text-based information, such as names, sentences, or any other character sequence.
#
#  They are used directly within code to specify text values or as part of operations involving text manipulation, such as concatenation, slicing, and formatting.
#
#
# **Variables:**
#  They are used to store and manage data of different types, including strings, numbers, boolean values, and more. Variables provide a way to keep track of changing values and perform operations on them.
#
#  They are used to store data values that can change during the execution of a program. Variables are essential for storing and accessing information dynamically, enabling the program to work with different data values without hard-coding them into the code.

# %% [markdown]
# **question 3. Describe three different data types.**

# %% [markdown]
# **ANS-**
#
# **int** - it can hold non decimal numbers EX-12,34
#
#  **string** - it can hold bunch of charcter and symbol in between single quates'' and double quates Ex-"gyevc@-",'buebc'
#
#
# **Bool**- it is hold boolen value  EX: Bool Flag= True

# %% [markdown]
#  **Question 4. What is an expression made up of? What do all expressions do?**

# %% [markdown]
# An expression  is a recipe that combines numbers, words, and actions like adding or subtracting to give you a single result.

# %% [markdown]
# **5.This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?**

# %% [markdown]
# expression is use one or more oprator and zero or more oprand and its combination give single reult
#
# Statements represent an action or command e.g print statements, assignment statements.
#
# print ('hello'), x = 1, spam = 10.

# %% [markdown]
# **6.After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1**

# %% [markdown]
# here bacon= 22
#
#      bacon+1 its give 23
#
#      bacon is not assign to any variable so bacon is 22

# %% [markdown]
# **7. What should the values of the following two terms be?
# &#39;spam&#39; + &#39;spamspam&#39;
# &#39;spam&#39; * 3**

# %%
"spam"*3
# Out:
# 'spamspamspam'

# %%
'spam'+'spamspam'
# Out:
# 'spamspamspam'

# %% [markdown]
# its give same result

# %% [markdown]
# **8. Why is eggs a valid variable name while 100 is invalid?**

# %% [markdown]
# Ans:Variable name can not start with digit its start with "_ or character"

# %% [markdown]
# **9.What three functions can be used to get the integer, floating-point number, or string
# version of a value?**

# %% [markdown]
# Ans:
# int(),float(),str()

# %% [markdown]
# **10. Why does this expression cause an error? How can you fix it?
# &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;**

# %% [markdown]
# here we need to typecast 99

# %%
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
