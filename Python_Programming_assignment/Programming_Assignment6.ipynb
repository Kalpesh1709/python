# %% [markdown]
# **1. Write a Python Program to Display Fibonacci Sequence Using Recursion?**

# %%
def Fabi_rec(i):
  if i<=1:
    return i
  else:
    return Fabi_rec(i-1)+Fabi_rec(i-2)

# %%
input_number =int(input("enter a number"))
if input_number<=0:
  print("enter a positive number")
else:
  print("fibonacci series")
  for i in range(input_number):
    print(Fabi_rec(i))
# Out:
# enter a number8
# fibonacci series
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %% [markdown]
# **2. Write a Python Program to Find Factorial of Number Using Recursion?**

# %%
def factorial(n):
  if n==1:
    return 1
  else:
    return n*factorial(n-1)

# %%
input_number =int(input("enter a number"))
if input_number<0:
  print("enter a positive number")
else:
  print("factorial of",input_number,"is",factorial(input_number))
# Out:
# enter a number6
# factorial of 6 is 720

# %% [markdown]
# **3. Write a Python Program to calculate your Body Mass Index?**

# %%
def BMI(weight,height):
  return weight/(height*height)
w=float(input("enter your weight in kg"))
h=float(input("enter your height in m"))
print("your BMI is",BMI(w,h))
if BMI(w,h)<18.5:
  print("underweight")
elif BMI(w,h)<25:
  print("normal")
elif BMI(w,h)<30:
  print("overweight")
# Out:
# enter your weight in kg64
# enter your height in m1.9
# your BMI is 17.72853185595568
# underweight

# %% [markdown]
# **4. Write a Python Program to calculate the natural logarithm of any number?**

# %%
import math
def natural_log(n):
  try:
    return math.log(n)
  except:
    print("enter a positive number")

# %%
x=natural_log(int(input("enter a number")))
print(x)
# Out:
# enter a number14
# 2.6390573296152584

# %% [markdown]
# **5. Write a Python Program for cube sum of first n natural numbers?**

# %%
def cube_sum(n):
  sum=0
  for i in range(1,n+1):
    sum+=i*i*i
  return sum

# %%
num=int(input("enter a number"))
print("cube sum of first",num,"natural numbers is",cube_sum(num))
# Out:
# enter a number5
# cube sum of first 5 natural numbers is 225
